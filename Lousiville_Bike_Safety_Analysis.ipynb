# %%
import pandas as pd

# %%
df = pd.read_csv('BCB_Survey.csv')
df.head()
# Out:
#             Timestamp Do you feel safe biking in Louisville?  \
# 0   9/28/2022 9:40:15                Only with a large group
# 1  9/28/2022 10:13:36                Only with a large group
# 2  9/28/2022 10:13:56                                     No
# 3  9/28/2022 10:14:37                                    Yes
# 4  9/28/2022 10:15:01                Only with a large group
#
#   What problems do you have with biking in Louisville currently?  \
# 0  Lights are too short, risk running red lights,...
# 1  Car traffic is too fast / dangerous, Bike lane...
# 2  Car traffic is too fast / dangerous, Bike lane...
# 3  Car traffic is too fast / dangerous, Bike lane...
# 4  Lights are too short, risk running red lights,...
#
#          What neighborhoods do you feel safe biking?  \
# 0  Indiana - New Albany, Indiana - Jeffersonville...
# 1  Highlands, Smoketown, Shelby Park, Indiana - N...
# 2            I do not feel safe biking in Louisville
# ...

# %%
data = pd.read_csv('BCB_Survey.csv')
print(data)
# Out:
#               Timestamp Do you feel safe biking in Louisville?  \
# 0     9/28/2022 9:40:15                Only with a large group
# 1    9/28/2022 10:13:36                Only with a large group
# 2    9/28/2022 10:13:56                                     No
# 3    9/28/2022 10:14:37                                    Yes
# 4    9/28/2022 10:15:01                Only with a large group
# ..                  ...                                    ...
# 136   9/29/2022 0:24:35                Only with a large group
# 137   9/29/2022 1:26:42                                    Yes
# 138   9/29/2022 5:55:29                                    Yes
# 139   9/29/2022 6:59:02                                     No
# 140   9/29/2022 7:40:46                                     No
#
#     What problems do you have with biking in Louisville currently?  \
# 0    Lights are too short, risk running red lights,...
# 1    Car traffic is too fast / dangerous, Bike lane...
# ...
